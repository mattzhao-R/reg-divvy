# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# col1_name = "headers"
# data[col1_name] = data.iloc[:,0]
# data = data.iloc[:,1:] #drop (now duplicated) first col
#
# #move column to front
# data = data[ [col1_name] + [ col for col in data.columns if col != col1_name ] ]
#
# #name of table
# tablename = "TABLE 2A ‐ Part 1\nDeclared Majors of College Students: Autumn 2017 (Students may declare multiple Majors )"

# %%
#name of table
tablename = "TABLE II-A ‐ Part 1\nDeclared Majors of College Students: Winter 2012 (Students may declare multiple Majors )"
tablename = "Table II-A\nDeclared Majors of College Students Winter 2012\n(Students may declare multiple majors)"

# %%
data.iloc[103,0]
# Out:
# 'Table II-A\nDeclared Majors of College Students Winter 2012\n(Students may declare multiple majors)'

# %%
def filename_gen(year,qint):
    #return a dictionary naming the quarter
    qdict = {}
    if qint==1:
            q_long = "Winter"
            q_short = "WIE"
    elif qint==2:
        q_long = "Spring"
        q_short = "SPE"
    elif qint==3:
        q_long = "Summer"
        q_short = "SUE"
    elif qint==4:
        q_long = "Autumn"
        q_short = "AUE"
    
    qdict["shorthand"] = f"{q_long} {year}"
    qdict["filename"] = f"{year}-{qint}{q_short} {q_long} Quarter {year} End-of-Quarter.xlsx"
    qdict["tablenames"] = [f"TABLE II-A ‐ Part 1\nDeclared Majors of College Students: {q_long} {year} (Students may declare multiple Majors )",
                          f"Table II-A\nDeclared Majors of College Students {q_long} {year}\n(Students may declare multiple majors)",
                          f"Table 2-A\nDeclared Majors of College Students {q_long} {year}\n(Students may declare multiple majors)",
                          f"Table 2-A\nDeclared Majors of College Students (Students may declare multiple majors) {q_long} {year}",
                          f"Table 2A\nDeclared Majors of College Students {q_long} {year}\n(Students may declare multiple majors)",
                          "Major",
                          f"TABLE 2A ‐ Part 1\nDeclared Majors of College Students: {q_long} {year} (Students may declare multiple Majors )",
                          f"Table 2‐A Part 1. Declared Majors of College Students\nCollege students may have multiple majors and minors\n{q_long} {year}",
                          f"TABLE 2A - Part 1\nDeclared Majors of College Students: {q_long} {year} (Students may declare multiple Majors )",
                          f"Table 2‐A Part 1. Declared Majors of College College students may have multiple majors and {q_long} {year}",
                          f"Table 2‐A Part 1. Declared Majors of College Students College students may have multiple majors and minors {q_long} {year}"
                          f"Table 2-A Declared Majors of College Students (Students may declare multiple majors) {q_long} {year}"]
    return qdict

# %%
def cleanrow(df,index_1):
    return df.iloc[index_1,:][df.iloc[index_1,:].notnull()]

def first_after(df,row_titles,start_index,get_index=False):
    indicies = []
    print(f"find first after {start_index}")
    for title in row_titles:
        print(title)
        for col in range(len(df.columns)):
            index_list = df[df.iloc[:,col] == title].index.to_list()

            if len(index_list) > 0:
                filtered = list(filter(lambda x : x >= start_index,index_list))
                if len(filtered) > 0:
                    index_1 = filtered[0]
                    indicies.append(index_1)
                    print(f"found {cleanrow(df,index_1)[-1]} at {index_1}")
                    #break
    
    #return based on param
    best_guess = min(indicies)
    if get_index:
        return best_guess
    else:
        return cleanrow(data,best_guess)

# %%
def findval(df,queries,start_index=0):
    indicies=[]
    try:
        #print(query)
        row = first_after(data,queries,start_index)
        print(row.iloc[-1])
        print(first_after(data,queries,start_index,get_index=True))
        indicies.append(first_after(data,queries,start_index,get_index=True))
    except UnboundLocalError:
        print("error")
        pass
        #continue
    return cleanrow(data,min(indicies))[-1]

# %% [markdown]
# def findval(df,queries,start_index=0):
#     indicies=[]
#     for query in queries:
#         try:
#             #print(query)
#             row = first_after(data,query,start_index)
#             print(row.iloc[-1])
#             indicies.append(first_after(data,query,start_index,get_index=True))
#         except UnboundLocalError:
#             continue
#     return cleanrow(data,min(indicies))[-1]

# %%
sumseslist = []
for year in range(2009,2020):
    print(year)
    data = pd.read_excel(f"{year}-3SUE Summer Quarter {year} End-of-Quarter.xlsx")
    queries = ["Pre-Collegiate Summer Student","Pre-Collegiate Summer Scholar","Pre‐Collegiate Summer Student"]
    sumseslist.append(findval(data,queries))
# Out:
# 2009
# 65
# 2010
# 73
# 2011
# 88
# 2012
# 98
# 2013
# 77
# 2014
# 47
# 2015
# 86
# 2016
# 136
# 2017
# 104.0
# 2018
# 66
# 2019
# 75

# %%
out = pd.DataFrame(list(zip(list(range(2009,2020)),sumseslist)),columns=["Year","Summer Session HS Count"])
#out.to_csv("Summer Session HS Enrollment.csv")
out
# Out:
#     Year  Summer Session HS Count
# 0   2009                     65.0
# 1   2010                     73.0
# 2   2011                     88.0
# 3   2012                     98.0
# 4   2013                     77.0
# 5   2014                     47.0
# 6   2015                     86.0
# 7   2016                    136.0
# 8   2017                    104.0
# 9   2018                     66.0
# 10  2019                     75.0

# %%
quarter_list = []
year_list = []
q_idc_list = []
cslist = []
totals = []
commonyrlist = []
for year in range(2009,2020):
    for qint in range(1,5):
        qdict=filename_gen(year,qint)
        
        quarter_list.append(qdict["shorthand"])
        year_list.append(year)
        q_idc_list.append(qint)
        print(qdict["shorthand"])
        
        #fetch correct dataset
        data = pd.read_excel(qdict["filename"])
        
        #set possible tablenames based on year and qint
        tablenames = qdict["tablenames"]
        
        #find CS relevant rows
        csqueries = ["Computer Science","Comp Sci"]
        totals_queries = ["TOTAL","Grand Total","Total","GRAND TOTAL","Sum","SUM","Sum:","Grand Total"]
        
        #call findval to find rightmost val in row.
        start_index = first_after(data,tablenames,0,get_index=True)
        cy_index = first_after(data,["Common Year"],0,get_index=True)
        
        cslist.append(findval(data,csqueries,start_index=start_index))
        totals.append(findval(data,totals_queries,start_index=cy_index))
        commonyrlist.append(findval(data,["Common Year"],start_index=start_index))
# Out:
# Winter 2009
# 33
# 5561
# 1246
# Spring 2009
# 41
# 5454
# 1102
# Summer 2009
# 3
# 384
# 60
# Autumn 2009
# 35
# 32
# 2201
# Winter 2010
# 32
# 5659
# 1950
# Spring 2010
# 38
# 5664
# 1402
# Summer 2010
# 4
# 400
# 91
# Autumn 2010
# 37
# 5967
# 2390
# Winter 2011
# 40
# 5907
# 2074
# Spring 2011
# 52
# 5834
# 1616
# Summer 2011
# 6
# 411
# 109
# Autumn 2011
# 57
# 6105
# 2494
# Winter 2012
# 63
# 9639
# 2132
# 3                   32                      2201
# 4                 5659                      1950
# 5                 5664                      1402
# 7                 5967                      2390
# 8                 5907                      2074
# 9                 5834                      1616
# 11                6105                      2494
# 12                9639                      2132
# 13                8920                      1600
# 15                9882                      2562
# 16                9644                      2157
# 17                9192                      1529
# 19                9458                      2405
# 20                9376                      2145
# 21                9022                      1305
# 23                6686                      2312
# 24                5722                      2072
# 25                6523                      1555
# 27                6803                      2634
# 28                6811                      2106
# 29                6703                      1484
# 31                6883                      2667
# 32                6903                      2227
# 33                6952                      1328
# 35                 307                      2766
# 36               15861                      2348
# 37                7521                      1433
# 39                8033                      2782
# 40                8092                      2335
# 41                8066                      1542
# 43                8377                      2828

# %%
############## A Buffer ##############################

# %%
qdict = filename_gen(2018,1)
data = pd.read_excel(qdict["filename"])

# %%
a = data.where(data=="Grand Total").dropna(how='all').dropna(axis=1)
data.iloc[a.index,:].dropna(how="all")
# Out:
#     WINTER QUARTER 2018 STATISTICAL REPORTS Unnamed: 1 Unnamed: 2  \
# 3                                       NaN        NaN        NaN
# 27                              Grand Total        NaN        NaN
# 29                    Academic Plan Primary        NaN        NaN
# 122                             Grand Total        NaN        NaN
# 124                                     NaN        NaN        NaN
# 189                                     NaN        NaN        NaN
# 191                                     NaN        NaN        NaN
# 227                                     NaN        NaN        NaN
# 229                   Academic Plan Primary        NaN        NaN
# 402                             Grand Total        NaN        NaN
# 404                   Academic Plan Primary        NaN        NaN
# 440                             Grand Total        NaN        NaN
# 442                    Study Abroad Program        NaN        NaN
# 489                             Grand Total        NaN        NaN
# 491                                     NaN        NaN        NaN
# 494                             Grand Total        NaN        NaN
# 496                                     NaN        NaN        NaN
# 525                             Grand Total        NaN        NaN
# 527                                     NaN        NaN        NaN
# 563                                     NaN        NaN        NaN
# 565                                     NaN        NaN        NaN
# 589                                     NaN        NaN        NaN
# 608                             Grand Total        NaN        NaN
# 633                             Grand Total        NaN        NaN
# 649                             Grand Total        NaN       3646
# 651                      Reason Not Counted        NaN        NaN
# 718                             Grand Total        NaN        NaN
#
#          Unnamed: 3      Unnamed: 4        Unnamed: 5 Unnamed: 6  \
# 3    Degree Seeking             NaN               NaN        NaN
# 27             6138             NaN               NaN        NaN
# 29              NaN             NaN               NaN        NaN
# 122             NaN             NaN               NaN        NaN
# 124             NaN             NaN               NaN        NaN
# 189             NaN             NaN               NaN        NaN
# 191             NaN             NaN               NaN        NaN
# 227             NaN             NaN               NaN        NaN
# 229             NaN             NaN               NaN        NaN
# 402             NaN             NaN               NaN        NaN
# 404             NaN             NaN               NaN    Masters
# 440             NaN             NaN               NaN         98
# 442             NaN  Undergraduates               NaN        NaN
# 489             NaN             151               NaN        NaN
# 491             NaN             NaN  Bachelor of Arts        NaN
# 494             NaN             NaN                47        NaN
# 496             NaN             NaN  Bachelor of Arts        NaN
# 525             NaN             NaN                51        NaN
# 527             NaN             NaN               NaN        NaN
# 563             NaN             NaN               NaN        NaN
# 565             NaN             NaN               NaN        NaN
# 589             NaN             NaN               NaN        NaN
# 589         NaN          NaN          NaN         NaN         NaN         NaN
# 608         NaN          NaN          NaN         NaN         NaN         NaN
# 633         NaN          NaN          NaN         NaN         NaN         NaN
# 649       15350          NaN          NaN         NaN           1         NaN
# 651         NaN          NaN          NaN         NaN         NaN         NaN
# 718         NaN          NaN          NaN         NaN         NaN         NaN
#
#     Unnamed: 70 Unnamed: 71
# 3           NaN         NaN
# 27          NaN         NaN
# 29          NaN         NaN
# 122         NaN         NaN
# 124         NaN         NaN
# 189         NaN         NaN
# 191         NaN         NaN
# 227         NaN         NaN
# 229         NaN         NaN
# 402         NaN         NaN
# 404         NaN         NaN
# 440         NaN         NaN
# 442         NaN         NaN
# 489         NaN         NaN
# 491         NaN         NaN
# 494         NaN         NaN
# 496         NaN         NaN
# 525         NaN         NaN
# 527         NaN         NaN
# 563         NaN         NaN
# 565         NaN         NaN
# 589         NaN         NaN
# 608         NaN         NaN
# 633         NaN         NaN
# 649         NaN         NaN
# 651         NaN         NaN
# 718         NaN         NaN
#
# [27 rows x 72 columns]

# %%
b = data.iloc[a.index,:].where(data=="Grand Total").dropna(how='all').dropna(axis=1)
b
# Out:
# Empty DataFrame
# Columns: []
# Index: [3, 27, 29, 122, 124, 189, 191, 227, 229, 402, 404, 440, 442, 489, 491, 494, 496, 525, 527, 563, 565, 589, 608, 633, 649, 651, 718]

# %%
start_index = first_after(data,qdict["tablenames"],0,get_index=True)
start_index
# Out:
# 123

# %%
findval(data,totals_queries,start_index=cy_index)
# Out:
# find first after 136
# TOTAL
# Grand Total
# found 15861 at 402
# found 380 at 589
# found 7455 at 189
# found 386 at 227
# found Grand Total at 442
# found Grand Total at 491
# found Grand Total at 191
# found Grand Total at 404
# found Grand Total at 651
# found Grand Total at 527
# found Grand Total at 565
# found Grand Total at 229
# Total
# found Grand Total at 527
# found Grand Total at 527
# found Total % at 616
# found Grand Total at 527
# GRAND TOTAL
# Sum
# SUM
# Sum:
# Grand Total
# found 15861 at 402
# found 380 at 589
# found 7455 at 189
# found 386 at 227
# found Grand Total at 442
# found Grand Total at 491
# found Grand Total at 191
# found Grand Total at 404
# found Grand Total at 651
# found Grand Total at 527
# found Grand Total at 565
# found Grand Total at 229
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-473-f1c1d44b4d81> in <module>
# ----> 1 findval(data,totals_queries,start_index=cy_index)
#
# <ipython-input-446-915999096154> in findval(df, queries, start_index)
#       3     try:
#       4         #print(query)
# ----> 5         row = first_after(data,queries,start_index)
#       6         print(row.iloc[-1])
#       7         print(first_after(data,queries,start_index,get_index=True))
#
# <ipython-input-472-8d96f99e8a97> in first_after(df, row_titles, start_index, get_index)
#      25
#      26     #return based on param
# ---> 27     best_guess = min(indicies)
#      28     if get_index:
#      29         return best_guess
#
# ValueError: min() arg is an empty sequence

# %%
indicies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-474-9c4cbb430428> in <module>
# ----> 1 indicies
#
# NameError: name 'indicies' is not defined

# %%
data[data.iloc[:,0] == "Grand Total"]
cleanrow(data,189)
data.iloc[189,13]
# Out:
# 'Grand Total'
